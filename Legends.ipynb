# %%
 import matplotlib.pyplot as plt

x = [1,2,3,4,5]
y = [45,67,33,67,12]
y1 = [41,60,13,66,13]
y2 = [11,66,23,46,43]
y3 = [21,46,53,36,73]

plt.figure(figsize = [6,4])

plt.plot(x,y, label = "male")
plt.plot(x,y1, label = "female")
plt.plot(x,y2, label = "kids")
plt.plot(x,y3, label = "third")

# plt.legend(loc = 10) // loc{0 -10 }
# plt.legend(["A1","A2","A3","A4"],ncols = 2)
plt.legend(bbox_to_anchor = (1,1),ncols =2, labelspacing = 2)
plt.show()
